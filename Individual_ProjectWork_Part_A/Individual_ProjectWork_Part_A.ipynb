# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhith1702/data690_likhith/blob/main/Individual_ProjectWork_Part_A/Individual_ProjectWork_Part_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Electricity production and Environmental impact:
#
# ##### Electricity production and consumption between USA and INDIA

# %% [markdown]
# # Countries Included.
# ### 1. INDIA
# ### 2. USA (United States of America)

# %% [markdown]
# # Name :
# Likhith Kumar Reddy A
# # Professor :
# Dr. Jay Wang
# # Class:
# Data-690-Fall-2021

# %% [markdown]
# # Time Frame for the case study.
# - 2010 to 2018

# %% [markdown]
# # Source :
# http://www.worlddev.xyz/

# %% [markdown]
# # Access to Electricity among the citizens of these countries.

# %% [markdown]
# The United States of America (USA) has 4.25% of the world’s population and is, by all means, a developed nation with a strong economy and technological innovations. While INDIA is a developing nation with 17.7% of the world’s population living in it, India and the USA are the second and third most populated countries. These countries with huge populations do consume huge amounts of electricity and this, in turn, has an irreparable impact on our environment.
#
#  Among these two countries, access to electricity is considerably high. In 2015, 100% of the population in the USA had access to electricity. While only 76.3% of the Indian population had access to electricity in the same year. However, we can see that india too had access to most of its population post 2015. As per 2019 nearly 98% of indian population had access to electricity.

# %% [markdown]
# ![newplot (22).png](data:image/png;base64,...)

# %% [markdown]
# ## Electricity consumption vs population

# %% [markdown]
# Even though there is an immense difference in the population of these two countries, the electricity consumption between them is not the same. The USA uses more than 13 times more electricity when compared to India.

# %% [markdown]
# ![newplot (5).png](data:image/png;base64,...)

# %% [markdown]
# Production disparity of electricity in 2010 between USA and India, show the power consumption and the indirect impact of it on environment amongst these two countries.

# %% [markdown]
# # Production of electricity among these two countries

# %% [markdown]
# While both the USA and India have different requirements and capabilities for generating electricity for their populations, there has been a wide disparity in the methods used by each country. To discuss this in detail, let us review the three different ways electricity is produced by each of these two countries. Fossil fuels, renewable sources and Nuclear fuel. Both countries have these capabilities.

# %% [markdown]
# ## FOSSIL FUELS

# %% [markdown]
# The primary fossil fuel that is used to produce electricity is coal, which is comparatively cheap to obtain, transport and handle. This also has low initial and running investment. Both the USA and India use coal for their electric production needs, and this also is the highest source of pollutants, as this creates more CO2 and other harmful gases.
#
# Among these two countries the consumption of electricity that is generated using fossil fuels is much higher in USA than in India.

# %% [markdown]
# ![newplot (17).png](data:image/png;base64,...)

# %% [markdown]
# ## Natural Gases and Oil

# %% [markdown]
# Production of electricity using natural gases and oil, in 2010 is comparatively low between both the countries.

# %% [markdown]
# ![newplot (6).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (7).png](data:image/png;base64,...)

# %% [markdown]
# ## Electricity produced in total by means of fossil fuels.

# %% [markdown]
# Among the two countries the production of electricity using coal, oil and gas is 81.2% in India and 70.27 in USA. Taking in to account the electricity produced, the USA uses much more fossil fuels to meet their electric production demand.

# %% [markdown]
# ![newplot (18).png](data:image/png;base64,...)

# %% [markdown]
# # RENEWABLE ENERGY SOURCES

# %% [markdown]
# ## Hydroelectric power production

# %% [markdown]
# Hydroelectric power plants in India produced 12.5% of the total electricity while the USA has 6.0% for the same. This shows that India has much potential for hydroelectric power production than the USA.

# %% [markdown]
# ![newplot (4).png](data:image/png;base64,...)

# %% [markdown]
# ## Other renewable sources used for power production

# %% [markdown]
# Electricity produced among the two countries using renewable source apart from hydroelectricity is considerably lesser than other means.

# %% [markdown]
# ![newplot (21).png](data:image/png;base64,...)

# %% [markdown]
# # NUCLEAR POWER PRODUCTION

# %% [markdown]
# Nuclear energy is the future of power production amongst many options. Both India and the USA have access and capabilities for the same. 19.2% of electricity produced in the USA is from nuclear sources. While India has a small footprint of 2.6%

# %% [markdown]
# ![newplot (20).png](data:image/png;base64,...)

# %% [markdown]
# # POLLUTION

# %% [markdown]
# In 2010, out of the total pollution created by India, 65.6% came from solid fuels. Similarly, the USA had 35.4% of its total pollution due to solid fuels used. Data indicates the amount of pollution created by each country with regards to their usage of fossil fuels. It shows that the USA has a larger footprint as they produce more electricity using fossil fuels to meet their needs.

# %% [markdown]
# ## CO2 Emmissions due to power production.

# %% [markdown]
# CO2 emissions from the production of electricity among these two countries are as follows. India produces around 51% of its total pollution due to electricity production whereas the USA is about 48.7% of its total.

# %% [markdown]
# ![newplot (13).png](data:image/png;base64,...)

# %% [markdown]
# ## CO2 emissions (metric tons per capita)

# %% [markdown]
# CO2 emissions (metric tons per capita) among these two countries show a  huge disparity. When it comes to the total CO2 produced, the USA takes the lead by several times when compared to India.

# %% [markdown]
# ![newplot (15).png](data:image/png;base64,...)

# %% [markdown]
# ## Co2 Emissions from 2010 to 2018

# %% [markdown]
# ![newplot (23).png](data:image/png;base64,...)

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# To conclude, the production and consumption of electricity are indirectly proportional to the pollution created by that country. We see that the more a country relies on fossil fuels to meet its energy demands, the more it contributes to pollution created. To cope with this, the best way to go about this is by shifting their energy production to renewable sources. However, they too pose challenges with regards to initial investment and other constraints. Even though nuclear fuel is an option that can be considered, it is both expensive and a hassle to maintain for any country, even more so to developing nations. The challenges with regards to the mining of fossil fuels and the consequent pollution from them is indeed a reality that need to be addressed by us.
